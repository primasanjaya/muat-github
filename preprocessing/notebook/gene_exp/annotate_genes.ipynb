# %%
import numpy as np
import pandas as pd
import os
import pdb

# %%
genes_ref_dir = '/csc/epitkane/data/genes_ref_GRCh37/'

# %%
gene_ref = 'Homo_sapiens.GRCh37.87.gtf.gz'

# %%
gene_data = pd.read_csv(genes_ref_dir + gene_ref)

# %%
gene_values = gene_data.iloc[4:]

# %%
gene_values.columns
# Out:
# Index(['#!genome-build GRCh37.p13'], dtype='object')

# %%
new = gene_values["#!genome-build GRCh37.p13"].str.split("\t", expand = True)

# %%
new8 = new[8].str.split(";", expand = True)

# %%
new8
# Out:
#                                 0                  1   \
# 4        gene_id "ENSG00000223972"   gene_version "4"
# 5        gene_id "ENSG00000223972"   gene_version "4"
# 6        gene_id "ENSG00000223972"   gene_version "4"
# 7        gene_id "ENSG00000223972"   gene_version "4"
# 8        gene_id "ENSG00000223972"   gene_version "4"
# ...                            ...                ...
# 2613764  gene_id "ENSG00000265557"   gene_version "1"
# 2613765  gene_id "ENSG00000265557"   gene_version "1"
# 2613766  gene_id "ENSG00000238643"   gene_version "1"
# 2613767  gene_id "ENSG00000238643"   gene_version "1"
# 2613768  gene_id "ENSG00000238643"   gene_version "1"
#
#                                        2                              3   \
# 4                     gene_name "DDX11L1"   gene_source "ensembl_havana"
# 5         transcript_id "ENST00000456328"         transcript_version "2"
# 6         transcript_id "ENST00000456328"         transcript_version "2"
# ...

# %%
new_data = pd.concat([new.iloc[:,0:8], new8],axis=1)

# %%
new_data.to_csv('/csc/epitkane/projects/PCAWG_geneexp/ref_genes_data.tsv',sep='\t')

# %%
sample_new_data = new_data.iloc[:1000,:]

# %%
sample_new_data.to_csv('/csc/epitkane/projects/PCAWG_geneexp/sample_ref_genes_data.tsv',sep='\t')

# %%
header_data = gene_data.iloc[:4]

# %%
header_data
# Out:
#                         #!genome-build GRCh37.p13
# 0                         #!genome-version GRCh37
# 1                           #!genome-date 2009-02
# 2  #!genome-build-accession NCBI:GCA_000001405.14
# 3                #!genebuild-last-updated 2013-09
